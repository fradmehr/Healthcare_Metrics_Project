# %%
# !pip install boto3 pandas

# %%
import boto3
import os

# =========================
# AWS Credentials & Config
# =========================
aws_access_key_id = "AKIATTZ7DLRMAGMYH2GE"
aws_secret_access_key = "uZKSX+l54B3nZ8GE0dH9+oVpHYZAdC0ygJRrEtK1"
region_name = "us-east-1"  # Change to your S3 bucket region
bucket_name = "healthcare-data-bucket-001"  # Replace with your bucket name
s3_prefix = "healthcare_data/raw/"  # Optional folder inside the bucket

# =========================
# File to upload
# =========================
file_name = "PBJ_Daily_Nurse_Staffing_Q2_2024.csv"
local_path = os.path.join(os.getcwd(), file_name)
s3_key = f"{s3_prefix}{file_name}"

# =========================
# Connect to S3
# =========================
s3 = boto3.client(
    "s3",
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# =========================
# Upload CSV file
# =========================
with open(local_path, "rb") as f:
    s3.upload_fileobj(f, bucket_name, s3_key)

print(f"✅ Uploaded {file_name} → s3://{bucket_name}/{s3_key}")
# Out:
# ✅ Uploaded PBJ_Daily_Nurse_Staffing_Q2_2024.csv → s3://healthcare-data-bucket-001/healthcare_data/raw/PBJ_Daily_Nurse_Staffing_Q2_2024.csv

# %% [markdown]
# ## 1. Loading Multiple csv files

# %%
import boto3
import os

# =========================
# AWS Credentials & Config
# =========================
aws_access_key_id = "AKIATTZ7DLRMAGMYH2GE"
aws_secret_access_key = "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"
region_name = "us-east-1"
bucket_name = "healthcare-data-bucket-001"
s3_prefix = "healthcare_data/raw/"

# =========================
# LIST OF FILES TO UPLOAD
# =========================
csv_files = [
    'jupyter_uploader_accessKeys (1).csv', 'jupyter_uploader_accessKeys.csv', 'NH_CitationDescriptions_Oct2024.csv', 
    'NH_CovidVaxAverages_20241027.csv', 'NH_CovidVaxProvider_20241027.csv', 'NH_DataCollectionIntervals_Oct2024.csv', 
    'NH_HlthInspecCutpointsState_Oct2024.csv', 'NH_Ownership_Oct2024.csv', 'NH_Penalties_Oct2024.csv', 
    'NH_ProviderInfo_Oct2024.csv', 'NH_QualityMsr_Claims_Oct2024.csv', 'NH_QualityMsr_MDS_Oct2024.csv', 
    'NH_StateUSAverages_Oct2024.csv', 'NH_SurveyDates_Oct2024.csv', 'NH_SurveySummary_Oct2024.csv', 
    'PBJ_Daily_Nurse_Staffing_Q2_2024.csv', 'Skilled_Nursing_Facility_Quality_Reporting_Program_National_Data_Oct2024.csv', 
    'Skilled_Nursing_Facility_Quality_Reporting_Program_Provider_Data_Oct2024.csv', 'stores.csv', 'Swing_Bed_SNF_data_Oct2024.csv'
]

# =========================
# Connect to S3
# =========================
s3 = boto3.client(
    "s3",
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# =========================
# Upload files one by one
# =========================
for file_name in csv_files:
    local_path = os.path.join(os.getcwd(), file_name)

    if not os.path.isfile(local_path):
        print(f"⚠️ File not found: {file_name}")
        continue

    s3_key = f"{s3_prefix}{file_name}"

    with open(local_path, "rb") as f:
        s3.upload_fileobj(f, bucket_name, s3_key)

    print(f"✅ Uploaded {file_name} → s3://{bucket_name}/{s3_key}")
# Out:
# ✅ Uploaded jupyter_uploader_accessKeys (1).csv → s3://healthcare-data-bucket-001/healthcare_data/raw/jupyter_uploader_accessKeys (1).csv
# ✅ Uploaded jupyter_uploader_accessKeys.csv → s3://healthcare-data-bucket-001/healthcare_data/raw/jupyter_uploader_accessKeys.csv
# ✅ Uploaded NH_CitationDescriptions_Oct2024.csv → s3://healthcare-data-bucket-001/healthcare_data/raw/NH_CitationDescriptions_Oct2024.csv
# ✅ Uploaded NH_CovidVaxAverages_20241027.csv → s3://healthcare-data-bucket-001/healthcare_data/raw/NH_CovidVaxAverages_20241027.csv
# ✅ Uploaded NH_CovidVaxProvider_20241027.csv → s3://healthcare-data-bucket-001/healthcare_data/raw/NH_CovidVaxProvider_20241027.csv
# ✅ Uploaded NH_DataCollectionIntervals_Oct2024.csv → s3://healthcare-data-bucket-001/healthcare_data/raw/NH_DataCollectionIntervals_Oct2024.csv
# ✅ Uploaded NH_HlthInspecCutpointsState_Oct2024.csv → s3://healthcare-data-bucket-001/healthcare_data/raw/NH_HlthInspecCutpointsState_Oct2024.csv
# ...

# %%
import os

csv_files = [
    f for f in os.listdir(os.getcwd())
    if f.lower().endswith(".csv")
]

print(csv_files)
# Out:
# ['department.csv', 'fact.csv', 'jupyter_uploader_accessKeys (1).csv', 'jupyter_uploader_accessKeys.csv', 'NH_CitationDescriptions_Oct2024.csv', 'NH_CovidVaxAverages_20241027.csv', 'NH_CovidVaxProvider_20241027.csv', 'NH_DataCollectionIntervals_Oct2024.csv', 'NH_HlthInspecCutpointsState_Oct2024.csv', 'NH_Ownership_Oct2024.csv', 'NH_Penalties_Oct2024.csv', 'NH_ProviderInfo_Oct2024.csv', 'NH_QualityMsr_Claims_Oct2024.csv', 'NH_QualityMsr_MDS_Oct2024.csv', 'NH_StateUSAverages_Oct2024.csv', 'NH_SurveyDates_Oct2024.csv', 'NH_SurveySummary_Oct2024.csv', 'PBJ_Daily_Nurse_Staffing_Q2_2024.csv', 'Skilled_Nursing_Facility_Quality_Reporting_Program_National_Data_Oct2024.csv', 'Skilled_Nursing_Facility_Quality_Reporting_Program_Provider_Data_Oct2024.csv', 'stores.csv', 'Swing_Bed_SNF_data_Oct2024.csv', 'test_healthcare.csv']

# %% [markdown]
# ## 2. Load file and Read files incrementally

# %%
import boto3
import os
from botocore.exceptions import ClientError

# =========================
# AWS Credentials & Config
# =========================
aws_access_key_id = "AKIATTZ7DLRMAGMYH2GE"
aws_secret_access_key = "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"
region_name = "us-east-1"
bucket_name = "healthcare-data-bucket-001"
s3_prefix = "healthcare_data/raw/"

# =========================
# LIST OF FILES TO UPLOAD
# =========================
csv_files = [
    'NH_CitationDescriptions_Oct2024.csv', 'NH_CovidVaxAverages_20241027.csv',
    'NH_CovidVaxProvider_20241027.csv', 'NH_DataCollectionIntervals_Oct2024.csv',
    'NH_HlthInspecCutpointsState_Oct2024.csv', 'NH_Ownership_Oct2024.csv',
    'NH_Penalties_Oct2024.csv', 'NH_ProviderInfo_Oct2024.csv',
    'NH_QualityMsr_Claims_Oct2024.csv', 'NH_QualityMsr_MDS_Oct2024.csv',
    'NH_StateUSAverages_Oct2024.csv', 'NH_SurveyDates_Oct2024.csv',
    'NH_SurveySummary_Oct2024.csv', 'PBJ_Daily_Nurse_Staffing_Q2_2024.csv',
    'Skilled_Nursing_Facility_Quality_Reporting_Program_National_Data_Oct2024.csv',
    'Skilled_Nursing_Facility_Quality_Reporting_Program_Provider_Data_Oct2024.csv',
    'stores.csv', 'Swing_Bed_SNF_data_Oct2024.csv'
]

# =========================
# Connect to S3
# =========================
s3 = boto3.client(
    "s3",
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# =========================
# Upload files incrementally
# =========================
for file_name in csv_files:
    local_path = os.path.join(os.getcwd(), file_name)

    if not os.path.isfile(local_path):
        print(f"⚠️ File not found: {file_name}")
        continue

    s3_key = f"{s3_prefix}{file_name}"

    # ✅ CHECK IF FILE ALREADY EXISTS IN S3
    try:
        s3.head_object(Bucket=bucket_name, Key=s3_key)
        print(f"⏩ Skipping (already exists): {file_name}")
        continue
    except ClientError as e:
        if e.response["Error"]["Code"] != "404":
            raise

    # ✅ UPLOAD ONLY NEW FILES
    with open(local_path, "rb") as f:
        s3.upload_fileobj(f, bucket_name, s3_key)

    print(f"✅ Uploaded {file_name} → s3://{bucket_name}/{s3_key}")
# Out:
# ⏩ Skipping (already exists): NH_CitationDescriptions_Oct2024.csv
# ⏩ Skipping (already exists): NH_CovidVaxAverages_20241027.csv
# ⏩ Skipping (already exists): NH_CovidVaxProvider_20241027.csv
# ⏩ Skipping (already exists): NH_DataCollectionIntervals_Oct2024.csv
# ⏩ Skipping (already exists): NH_HlthInspecCutpointsState_Oct2024.csv
# ⏩ Skipping (already exists): NH_Ownership_Oct2024.csv
# ⏩ Skipping (already exists): NH_Penalties_Oct2024.csv
# ⏩ Skipping (already exists): NH_ProviderInfo_Oct2024.csv
# ⏩ Skipping (already exists): NH_QualityMsr_Claims_Oct2024.csv
# ⏩ Skipping (already exists): NH_QualityMsr_MDS_Oct2024.csv
# ⏩ Skipping (already exists): NH_StateUSAverages_Oct2024.csv
# ⏩ Skipping (already exists): NH_SurveyDates_Oct2024.csv
# ⏩ Skipping (already exists): NH_SurveySummary_Oct2024.csv
# ⏩ Skipping (already exists): PBJ_Daily_Nurse_Staffing_Q2_2024.csv
# ⏩ Skipping (already exists): Skilled_Nursing_Facility_Quality_Reporting_Program_National_Data_Oct2024.csv
# ...
